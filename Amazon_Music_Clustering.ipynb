# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
music_data = pd.read_csv("F:/Python_WC/Amazon Music Clustering/Amazon_Music_Clustering/single_genre_artists.csv")

# %%
music_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95837 entries, 0 to 95836
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_songs            95837 non-null  object
#  1   name_song           95837 non-null  object
#  2   popularity_songs    95837 non-null  int64
#  3   duration_ms         95837 non-null  int64
#  4   explicit            95837 non-null  int64
#  5   id_artists          95837 non-null  object
#  6   release_date        95837 non-null  object
#  7   danceability        95837 non-null  float64
#  8   energy              95837 non-null  float64
#  9   key                 95837 non-null  int64
#  10  loudness            95837 non-null  float64
#  11  mode                95837 non-null  int64
#  12  speechiness         95837 non-null  float64
#  13  acousticness        95837 non-null  float64
#  14  instrumentalness    95837 non-null  float64
# ...

# %%
music_data.columns
# Out:
# Index(['id_songs', 'name_song', 'popularity_songs', 'duration_ms', 'explicit',
#        'id_artists', 'release_date', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'time_signature', 'followers', 'genres',
#        'name_artists', 'popularity_artists'],
#       dtype='object')

# %%
music_data.dtypes
# Out:
# id_songs               object
# name_song              object
# popularity_songs        int64
# duration_ms             int64
# explicit                int64
# id_artists             object
# release_date           object
# danceability          float64
# energy                float64
# key                     int64
# loudness              float64
# mode                    int64
# speechiness           float64
# acousticness          float64
# instrumentalness      float64
# liveness              float64
# valence               float64
# tempo                 float64
# time_signature          int64
# followers             float64
# genres                 object
# name_artists           object
# popularity_artists      int64
# dtype: object

# %%
music_data.shape
# Out:
# (95837, 23)

# %%
music_data.describe()
# Out:
#        popularity_songs   duration_ms      explicit  danceability  \
# count      95837.000000  9.583700e+04  95837.000000  95837.000000
# mean          26.066394  2.087320e+05      0.029644      0.586853
# std           16.254133  1.177526e+05      0.169604      0.155422
# min            0.000000  6.373000e+03      0.000000      0.000000
# 25%           13.000000  1.573330e+05      0.000000      0.488000
# 50%           26.000000  2.040000e+05      0.000000      0.605000
# 75%           37.000000  2.502670e+05      0.000000      0.700000
# max           98.000000  4.800118e+06      1.000000      0.991000
#
#              energy           key      loudness          mode   speechiness  \
# count  95837.000000  95837.000000  95837.000000  95837.000000  95837.000000
# mean       0.541083      5.196782    -10.157862      0.648069      0.168832
# std        0.236304      3.534923      4.748798      0.477575      0.275417
# ...

# %%
music_data.isnull().sum()
# Out:
# id_songs              0
# name_song             0
# popularity_songs      0
# duration_ms           0
# explicit              0
# id_artists            0
# release_date          0
# danceability          0
# energy                0
# key                   0
# loudness              0
# mode                  0
# speechiness           0
# acousticness          0
# instrumentalness      0
# liveness              0
# valence               0
# tempo                 0
# time_signature        0
# followers             0
# genres                0
# name_artists          0
# popularity_artists    0
# dtype: int64

# %%
music_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
music_data.drop(columns=['id_songs','id_artists','release_date','name_artists'],inplace=True)

# %%
music_data
# Out:
#                name_song  popularity_songs  duration_ms  explicit  \
# 0                La Java                 0       161427         0
# 1               En Douce                 0       223440         0
# 2          J'en Ai Marre                 0       208267         0
# 3       Ils n'ont pas ca                 0       161933         0
# 4              La belote                 0       167973         0
# ...                  ...               ...          ...       ...
# 95832             Freaks                70       174800         0
# 95833                下雨天                50       265846         0
# 95834   The Cutest Puppy                67        82500         0
# 95835  John Brown's Song                66       185250         0
# 95836                云与海                50       258267         0
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.563  0.1840    4   -13.757     1       0.0512         0.993
# ...

# %%
music_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95837 entries, 0 to 95836
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name_song           95837 non-null  object
#  1   popularity_songs    95837 non-null  int64
#  2   duration_ms         95837 non-null  int64
#  3   explicit            95837 non-null  int64
#  4   danceability        95837 non-null  float64
#  5   energy              95837 non-null  float64
#  6   key                 95837 non-null  int64
#  7   loudness            95837 non-null  float64
#  8   mode                95837 non-null  int64
#  9   speechiness         95837 non-null  float64
#  10  acousticness        95837 non-null  float64
#  11  instrumentalness    95837 non-null  float64
#  12  liveness            95837 non-null  float64
#  13  valence             95837 non-null  float64
#  14  tempo               95837 non-null  float64
# ...

# %%
music_data.columns
# Out:
# Index(['name_song', 'popularity_songs', 'duration_ms', 'explicit',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'time_signature', 'followers', 'genres', 'popularity_artists'],
#       dtype='object')

# %%
music_data.value_counts().T
# Out:
# name_song                        popularity_songs  duration_ms  explicit  danceability  energy  key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  valence  tempo    time_signature  followers  genres                  popularity_artists
# Bibi Blocksberg Lied             32                88874        0         0.704         0.684   10   -12.502   1     0.0817       0.1460        0.000000          0.4240    0.712    134.507  4               128057.0   ['hoerspiel']           82                    9
#                                  31                88874        0         0.704         0.684   10   -12.502   1     0.0817       0.1460        0.000000          0.4240    0.712    134.507  4               128057.0   ['hoerspiel']           82                    7
# ...

# %%
#Convert duration from milliseconds to minutes

music_data["duration_min"] = music_data["duration_ms"] / 60000.0

# %%
features = [
    "danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","duration_min"
]
x=music_data[features].copy()

# %%
for col in features:
    plt.figure(figsize=(7,4))
    sns.histplot(music_data[col],bins=50,kde=True)
    plt.title(f'Histogram of {col}')
    plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(x.corr(), annot=True, cmap="viridis")
plt.title("Correlation Heatmap (Numerical Features)")
plt.show()

# %% [markdown]
# ## Preprocessing using StandardScalar()

# %%
from sklearn.preprocessing import StandardScaler
# Columns used for clustering in your original df
scaler = StandardScaler()
music_data_scaled= scaler.fit_transform(music_data[features])  # fit only on these numeric features and transform uploaded song with same columns

# %%
music_data_scaled.T
# Out:
# array([[-0.15347598, -1.02851842, -0.48805103, ...,  0.14249425,
#         -0.15991012, -0.17277839],
#        [-1.51112816, -1.52805562, -1.41802711, ..., -2.21700341,
#         -2.14971674, -0.09768491],
#        [-0.75790895, -1.09862851, -1.12789922, ..., -3.87787243,
#         -3.24149759,  0.56580125],
#        ...,
#        [ 0.32128698, -0.57745518, -0.37594348, ...,  1.27242218,
#         -0.7588157 , -1.46410663],
#        [ 0.51500516, -1.2944868 , -1.56000306, ..., -1.62041993,
#         -1.78348586,  0.47552221],
#        [-0.40173462,  0.12490637, -0.00394925, ..., -1.07201656,
#         -0.19941949,  0.4206722 ]], shape=(10, 95837))

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA(n_components=2,random_state=42)
X_pca = pca.fit_transform(music_data_scaled)

plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1],s=5,alpha=0.7, edgecolor='k') # s is the size of points
#plt.scatter(music_data['pca1'], music_data['pca2'], c=music_data['cluster'], cmap='tab10', alpha=0.6, edgecolor='k')
plt.title('PCA Projection of Songs Before Clustering')
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()

# %%
# K-Means Clustering with Elbow Method and Silhouette Score
# -------------------------------
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
sse=[] # Sum of squared distances to closest cluster center [the lower the sse value the better the model and we chose that k value]
sil_scores = []   # Silhouette scores for each k
K_Values = range(2,6)
for k in K_Values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)# n_init specifies the number of times the k-means algorithm will be run with different centroid seeds
    kmeans.fit(music_data_scaled)
    sse.append(kmeans.inertia_)
    sil_avg = silhouette_score(music_data_scaled, kmeans.labels_)
    sil_scores.append(sil_avg)
    print(f"k={k}, Silhouette Score: {sil_avg:.4f}")

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(K_Values, sse , marker='o')
plt.title('Elbow Method — SSE  vs k')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('SSE')
plt.grid(True)
plt.show()

plt.subplot(1,2,2)
plt.plot(K_Values, sil_scores, 'ro-', linewidth=2, markersize=8)
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Analysis for Optimal k')
plt.grid(True)
plt.show()
# Out:
# k=2, Silhouette Score: 0.2032
# k=3, Silhouette Score: 0.2423
# k=4, Silhouette Score: 0.2310
# k=5, Silhouette Score: 0.1864

# %%
# Pick k where:
# - Silhouette is highest
# - Elbow is visible

best_k = sil_scores.index(max(sil_scores)) + 2
print("Best k =", best_k)
# Out:
# Best k = 3

# %%
# --------------------------------------
# 7. Apply K-Means with optimal k
# --------------------------------------
kmeans_model = KMeans(n_clusters=best_k, random_state=42,n_init=20)
cluster_labels = kmeans_model.fit_predict(music_data_scaled)
music_data['cluster'] = cluster_labels
music_data.to_csv("amazon_music_clusters_k3.csv", index=False)
print("\n✅ Cluster labels added to dataframe and saved as 'amazon_music_clusters_full_k3.csv'")
# Out:
# ✅ Cluster labels added to dataframe and saved as 'amazon_music_clusters_full_k3.csv'

# %%
cluster_labels
# Out:
# array([1, 1, 1, ..., 1, 1, 1], shape=(95837,), dtype=int32)

# %%
from sklearn.metrics import davies_bouldin_score
davies_bouldin_score = davies_bouldin_score(music_data_scaled, cluster_labels)
print("Davies-Bouldin Score:", davies_bouldin_score)
# Out:
# Davies-Bouldin Score: 1.5705032224190087

# %%
# === Cluster Summary: Feature Means per Cluster ===
cluster_summary = music_data.groupby('cluster')[features].mean().reset_index()
print("\n=== Cluster Feature Means ===")
print(cluster_summary)

# === Visualize Cluster Profiles with Heatmap ===
plt.figure(figsize=(12,6))
sns.heatmap(cluster_summary.set_index('cluster'), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Average Feature Values per Cluster")
plt.show()

# === Cluster Sizes ===
cluster_counts = music_data['cluster'].value_counts().sort_index()
plt.figure(figsize=(6,4))
sns.barplot(x=cluster_counts.index, y=cluster_counts.values,hue=cluster_counts.index, palette='viridis')
plt.title("Number of Songs per Cluster")
plt.xlabel("Cluster")
plt.ylabel("Count")
plt.show()

print("\nCluster sizes:")
print(cluster_counts)


# === PCA Visualization of Clusters ===
pca = PCA(n_components=2,random_state=42)
x_pca = pca.fit_transform(music_data_scaled)
plt.figure(figsize=(8,6))
plt.xlabel("PCA1")
plt.scatter(x=x_pca[:,0],y=x_pca[:,1], c=music_data['cluster'], cmap='tab10', alpha=0.6, edgecolor='k') 
#sns.scatterplot(x=x_pca[:,0],y=x_pca[:,1],hue=df['cluster'],palette='viridis',s=10,alpha=0.7)
plt.title("PCA Projection of Songs Colored by KMeans Clusters")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.colorbar(label="Cluster")  # adds legend for clusters
plt.show()


# ===  Interpret Cluster Characteristics ===
print("\n=== Cluster Interpretation Suggestions ===")
for c in cluster_summary['cluster']:
    print(f"\nCluster {c}:")
    top_features = cluster_summary.loc[cluster_summary['cluster']==c, features].T
    top_features = top_features[top_features[c] > top_features[c].mean()].sort_values(by=c, ascending=False)
    print("   → Dominant Features:", list(top_features.index[:3]))

# === Save Cluster Profiles for Report ===
cluster_summary.to_csv("cluster_feature_summary.csv", index=False)
print("\n✅ Cluster summary saved as 'cluster_feature_summary.csv'")
# Out:
# === Cluster Feature Means ===
#    cluster  danceability    energy   loudness  speechiness  acousticness  \
# 0        0      0.664259  0.466618 -13.364416     0.829938      0.585916
# 1        1      0.486376  0.311307 -13.203705     0.060157      0.749176
# 2        2      0.627372  0.693677  -7.606166     0.075051      0.258438
#
#    instrumentalness  liveness   valence       tempo  duration_min
# 0          0.001384  0.435523  0.584054  100.388816      1.625374
# 1          0.168526  0.182115  0.413258  111.941246      3.727545
# 2          0.050698  0.199842  0.666450  124.913029      3.774662
# Cluster sizes:
# cluster
# 0    12514
# 1    30815
# 2    52508
# Name: count, dtype: int64
# === Cluster Interpretation Suggestions ===
#
# Cluster 0:
#    → Dominant Features: ['tempo']
#
# Cluster 1:
#    → Dominant Features: ['tempo']
#
# Cluster 2:
#    → Dominant Features: ['tempo']
#
# ✅ Cluster summary saved as 'cluster_feature_summary.csv'

# %%
cluster_names = {
    0: "Energetic & Danceable",
    1: "Calm Acoustic",
    2: "Balanced Mainstream"
}
music_data['cluster_label'] = music_data['cluster'].map(cluster_names)

#  Cluster summary statistics
final_summary = (
    music_data.groupby(['cluster','cluster_label'])
      [features]
      .mean()
      .round(3)
      .reset_index()
)
print("\n=== Final Cluster Summary ===")
print(final_summary)

# Cluster sizes
cluster_sizes = music_data['cluster'].value_counts().sort_index()
print("\nCluster Sizes:")
print(cluster_sizes)

#  Export Final Outputs
music_data.to_csv("amazon_music_final_clusters.csv", index=False)
final_summary.to_csv("amazon_music_final_summary.csv", index=False)
print("\n✅ Files exported:")
print("  • amazon_music_final_clusters.csv — all songs with cluster labels")
print("  • amazon_music_final_summary.csv — cluster mean feature summary")
# Out:
# === Final Cluster Summary ===
#    cluster          cluster_label  danceability  energy  loudness  \
# 0        0  Energetic & Danceable         0.664   0.467   -13.364
# 1        1          Calm Acoustic         0.486   0.311   -13.204
# 2        2    Balanced Mainstream         0.627   0.694    -7.606
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.830         0.586             0.001     0.436    0.584  100.389
# 1        0.060         0.749             0.169     0.182    0.413  111.941
# 2        0.075         0.258             0.051     0.200    0.666  124.913
#
#    duration_min
# 0         1.625
# 1         3.728
# 2         3.775
#
# Cluster Sizes:
# cluster
# 0    12514
# 1    30815
# 2    52508
# Name: count, dtype: int64
#
# ✅ Files exported:
#   • amazon_music_final_clusters.csv — all songs with cluster labels
#   • amazon_music_final_summary.csv — cluster mean feature summary

# %%
#  Quick insight report generation
print("\n🧠 Cluster Insights Summary:")
for _, row in final_summary.iterrows():
    c = int(row['cluster'])
    label = row['cluster_label']
    print(f"\nCluster {c} ({label}):")
    print(f"  🎵 Danceability={row['danceability']:.2f}, Energy={row['energy']:.2f}, "
          f"Acousticness={row['acousticness']:.2f}, Tempo={row['tempo']:.1f} BPM, Valence={row['valence']:.2f}")
# Out:
# 🧠 Cluster Insights Summary:
#
# Cluster 0 (Energetic & Danceable):
#   🎵 Danceability=0.66, Energy=0.47, Acousticness=0.59, Tempo=100.4 BPM, Valence=0.58
#
# Cluster 1 (Calm Acoustic):
#   🎵 Danceability=0.49, Energy=0.31, Acousticness=0.75, Tempo=111.9 BPM, Valence=0.41
#
# Cluster 2 (Balanced Mainstream):
#   🎵 Danceability=0.63, Energy=0.69, Acousticness=0.26, Tempo=124.9 BPM, Valence=0.67

# %%
import joblib
joblib.dump(kmeans_model, 'kmeans_model.pkl')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']
